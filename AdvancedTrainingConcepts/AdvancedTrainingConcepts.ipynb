# %% [markdown]
# ### Initial Setup

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-06ca0d50-cfe0-b60a-47a7-12b0d0104c63)

# %%
# !git clone "https://github.com/akshatjaipuria/ComputerVision101.git"
# Out:
# fatal: destination path 'ComputerVision101' already exists and is not an empty directory.

# %%
# %cd '/content/ComputerVision101'
# Out:
# /content/ComputerVision101

# %% [markdown]
# ### Dataloaders

# %%
import torch
import torchvision
import torch.nn as nn

# %%
device = torch.device ("cuda:0" if torch.cuda.is_available () else "cpu")
print (f"Device: {device}")
# Out:
# Device: cuda:0

# %%
# Mean and STD for CIFAR-10
mean = (0.4914, 0.48216, 0.44653)
std = (0.24703, 0.24349, 0.26159)

# Class labels for CIFAR-10
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
from pytorch_cv.main import TrainTransforms, TestTransforms
from pytorch_cv.utils.data_loader import GetDataLoaders

train_loader, test_loader = GetDataLoaders(torchvision.datasets.CIFAR10, TrainTransforms(mean, std), TestTransforms(mean, std))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# CUDA Available? True

# %%
from pytorch_cv.utils.visualizer import DisplayData

DisplayData (train_loader, classes, [mean, std])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Model and training

# %%
from pytorch_cv.models.resnet import ResNet18
net = ResNet18()

# %%
from pytorch_cv.utils.utils import PrintSummary
net.to(device)
PrintSummary(net, (3, 32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
#       BatchNorm2d-14          [-1, 128, 16, 16]             256
#            Conv2d-15          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-16          [-1, 128, 16, 16]             256
#            Conv2d-17          [-1, 128, 16, 16]           8,192
#       BatchNorm2d-18          [-1, 128, 16, 16]             256
#        BasicBlock-19          [-1, 128, 16, 16]               0
#            Conv2d-20          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-21          [-1, 128, 16, 16]             256
#            Conv2d-22          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-23          [-1, 128, 16, 16]             256
#        BasicBlock-24          [-1, 128, 16, 16]               0
#            Conv2d-25            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-26            [-1, 256, 8, 8]             512
#            Conv2d-27            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-28            [-1, 256, 8, 8]             512
#            Conv2d-29            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-30            [-1, 256, 8, 8]             512
#        BasicBlock-31            [-1, 256, 8, 8]               0
#            Conv2d-32            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-33            [-1, 256, 8, 8]             512
#            Conv2d-34            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-35            [-1, 256, 8, 8]             512
#        BasicBlock-36            [-1, 256, 8, 8]               0
#            Conv2d-37            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-38            [-1, 512, 4, 4]           1,024
#            Conv2d-39            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-40            [-1, 512, 4, 4]           1,024
#            Conv2d-41            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-42            [-1, 512, 4, 4]           1,024
#        BasicBlock-43            [-1, 512, 4, 4]               0
#            Conv2d-44            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-45            [-1, 512, 4, 4]           1,024
#            Conv2d-46            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-47            [-1, 512, 4, 4]           1,024
#        BasicBlock-48            [-1, 512, 4, 4]               0
#            Linear-49                   [-1, 10]           5,130
# ================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 11.25
# Params size (MB): 42.63
# Estimated Total Size (MB): 53.89
# ----------------------------------------------------------------
# None

# %%
from pytorch_cv.utils.trainer import TrainModel

data_dict = TrainModel(net, train_loader, test_loader, nn.CrossEntropyLoss, False, 20, 0.01, device)
# Out:
# -------------- Epoch 1 --------------
# Train: Loss=1.4553 Batch_id=390 Accuracy=34.28: 100%|██████████| 391/391 [00:44<00:00,  8.83it/s]
# Test set: Average loss: 1.4382, Accuracy: 4890/10000 (48.90%)
#
# -------------- Epoch 2 --------------
# Train: Loss=1.3467 Batch_id=390 Accuracy=45.95: 100%|██████████| 391/391 [00:44<00:00,  8.86it/s]
# Test set: Average loss: 1.3251, Accuracy: 5324/10000 (53.24%)
#
# -------------- Epoch 3 --------------
# Train: Loss=1.3133 Batch_id=390 Accuracy=52.61: 100%|██████████| 391/391 [00:44<00:00,  8.84it/s]
# Test set: Average loss: 1.8040, Accuracy: 5076/10000 (50.76%)
#
# -------------- Epoch 4 --------------
# Train: Loss=1.2541 Batch_id=390 Accuracy=56.73: 100%|██████████| 391/391 [00:44<00:00,  8.84it/s]
# Test set: Average loss: 0.9415, Accuracy: 6808/10000 (68.08%)
#
# -------------- Epoch 5 --------------
# Train: Loss=0.9912 Batch_id=390 Accuracy=59.68: 100%|██████████| 391/391 [00:44<00:00,  8.87it/s]
# Test set: Average loss: 1.1106, Accuracy: 6419/10000 (64.19%)
#
# -------------- Epoch 6 --------------
# Train: Loss=1.1465 Batch_id=390 Accuracy=62.02: 100%|██████████| 391/391 [00:44<00:00,  8.87it/s]
# Test set: Average loss: 1.1025, Accuracy: 6717/10000 (67.17%)
#
# -------------- Epoch 7 --------------
# Train: Loss=1.2137 Batch_id=390 Accuracy=64.14: 100%|██████████| 391/391 [00:44<00:00,  8.82it/s]
# Test set: Average loss: 0.6595, Accuracy: 7738/10000 (77.38%)
#
# -------------- Epoch 8 --------------
# Train: Loss=1.1902 Batch_id=390 Accuracy=65.60: 100%|██████████| 391/391 [00:44<00:00,  8.83it/s]
# Test set: Average loss: 0.7775, Accuracy: 7466/10000 (74.66%)
#
# -------------- Epoch 9 --------------
# Train: Loss=0.9849 Batch_id=390 Accuracy=67.08: 100%|██████████| 391/391 [00:44<00:00,  8.86it/s]
# Test set: Average loss: 0.6793, Accuracy: 7716/10000 (77.16%)
#
# -------------- Epoch 10 --------------
# Train: Loss=0.8486 Batch_id=390 Accuracy=68.50: 100%|██████████| 391/391 [00:44<00:00,  8.80it/s]
# Test set: Average loss: 0.7654, Accuracy: 7408/10000 (74.08%)
#
# -------------- Epoch 11 --------------
# Train: Loss=0.6572 Batch_id=390 Accuracy=69.35: 100%|██████████| 391/391 [00:44<00:00,  8.82it/s]
# Test set: Average loss: 0.6000, Accuracy: 8024/10000 (80.24%)
#
# -------------- Epoch 12 --------------
# Train: Loss=0.9717 Batch_id=390 Accuracy=70.14: 100%|██████████| 391/391 [00:44<00:00,  8.86it/s]
# Test set: Average loss: 0.6132, Accuracy: 7970/10000 (79.70%)
#
# -------------- Epoch 13 --------------
# Train: Loss=0.8124 Batch_id=390 Accuracy=70.67: 100%|██████████| 391/391 [00:44<00:00,  8.84it/s]
# Test set: Average loss: 0.6709, Accuracy: 7844/10000 (78.44%)
#
# -------------- Epoch 14 --------------
# Train: Loss=0.8004 Batch_id=390 Accuracy=72.00: 100%|██████████| 391/391 [00:44<00:00,  8.76it/s]
# Test set: Average loss: 0.5548, Accuracy: 8137/10000 (81.37%)
#
# -------------- Epoch 15 --------------
# Train: Loss=0.6430 Batch_id=390 Accuracy=72.55: 100%|██████████| 391/391 [00:44<00:00,  8.84it/s]
# Test set: Average loss: 0.5438, Accuracy: 8200/10000 (82.00%)
#
# -------------- Epoch 16 --------------
# Train: Loss=0.8645 Batch_id=390 Accuracy=73.23: 100%|██████████| 391/391 [00:44<00:00,  8.87it/s]
# Test set: Average loss: 0.6341, Accuracy: 8031/10000 (80.31%)
#
# -------------- Epoch 17 --------------
# Train: Loss=0.6860 Batch_id=390 Accuracy=73.60: 100%|██████████| 391/391 [00:44<00:00,  8.84it/s]
# Test set: Average loss: 0.5679, Accuracy: 8175/10000 (81.75%)
#
# -------------- Epoch 18 --------------
# Train: Loss=0.7561 Batch_id=390 Accuracy=74.49: 100%|██████████| 391/391 [00:44<00:00,  8.82it/s]
# Test set: Average loss: 0.5337, Accuracy: 8264/10000 (82.64%)
#
# -------------- Epoch 19 --------------
# Train: Loss=0.7621 Batch_id=390 Accuracy=74.88: 100%|██████████| 391/391 [00:44<00:00,  8.85it/s]
# Test set: Average loss: 0.4994, Accuracy: 8345/10000 (83.45%)
#
# -------------- Epoch 20 --------------
# Train: Loss=0.6485 Batch_id=390 Accuracy=75.31: 100%|██████████| 391/391 [00:44<00:00,  8.80it/s]
# Test set: Average loss: 0.5256, Accuracy: 8295/10000 (82.95%)

# %% [markdown]
# ### Misclassified images (from Test set)

# %%
from pytorch_cv.utils.visualizer import DisplayIncorrectPredictions

DisplayIncorrectPredictions (data_dict['incorrect_pred'], classes, [mean, std])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Loss/Accuracy graphs

# %%
from pytorch_cv.utils.visualizer import PlotTrainVsTest

# %%
# Accuracy curves
PlotTrainVsTest (("Training Accuracy", data_dict['train_acc']), ("Test Accuracy", data_dict['test_acc']))

# %%
# Loss curves
PlotTrainVsTest (("Training Loss", data_dict['train_loss']), ("Test Loss", data_dict['test_loss']))

# %% [markdown]
# ### GradCam

# %%
from pytorch_cv.utils.gradcam import GradDisplay

# %%
test_iter=iter(test_loader)

# %%
img, lab = next(test_iter)

# %%
gradcam_inst = GradDisplay(net, ['layer1', 'layer2', 'layer3', 'layer4'], device, mean, std)
images = img[11:21]
gradcam_inst(images, 'grad_cam')
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1117: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
